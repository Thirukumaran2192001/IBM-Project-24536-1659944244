# %% [markdown]
# 1. Download the dataset: Dataset : churn_modeling.csv

# %% [markdown]
# 2. Load the dataset.

# %%
import pandas as pd

# %%
dataset = pd.read_csv("Churn_Modelling.csv") # import may occures in different ways according ,where we store the data set
dataset.head()
# Out:
#    RowNumber  CustomerId   Surname  CreditScore Geography  Gender  Age  \
# 0          1    15634602  Hargrave          619    France  Female   42
# 1          2    15647311      Hill          608     Spain  Female   41
# 2          3    15619304      Onio          502    France  Female   42
# 3          4    15701354      Boni          699    France  Female   39
# 4          5    15737888  Mitchell          850     Spain  Female   43
#
#    Tenure    Balance  NumOfProducts  HasCrCard  IsActiveMember  \
# 0       2       0.00              1          1               1
# 1       1   83807.86              1          0               1
# 2       8  159660.80              3          1               0
# 3       1       0.00              2          0               0
# 4       2  125510.82              1          1               1
#
#    EstimatedSalary  Exited
# 0        101348.88       1
# 1        112542.58       0
# 2        113931.57       1
# 3         93826.63       0
# ...

# %% [markdown]
# 3. Perform Below Visualizations.
# ● Univariate Analysis
# ● Bi - Variate Analysis
# ● Multi - Variate Analysis

# %%
import seaborn as sns

# %%
# univariate
sns.displot(dataset['CreditScore'])

# %%
sns.displot(dataset['NumOfProducts'])

# %%
# bi variate
sns.relplot(x="CreditScore",y='Age',data=dataset)

# %%
sns.relplot(x="CreditScore",y='Age',hue="IsActiveMember",data=dataset)

# %%
sns.catplot(x="Gender",y='Age',data=dataset)

# %%
# multivariate
sns.pairplot(data=dataset,hue="Exited")

# %% [markdown]
# 4. Perform descriptive statistics on the dataset.

# %%
import pandas as pd
import numpy as np
ds = pd.read_csv("Churn_Modelling.csv")  # import may occures in different ways according ,where we store the data set
ds.head(2)
# Out:
#    RowNumber  CustomerId   Surname  CreditScore Geography  Gender  Age  \
# 0          1    15634602  Hargrave          619    France  Female   42
# 1          2    15647311      Hill          608     Spain  Female   41
#
#    Tenure   Balance  NumOfProducts  HasCrCard  IsActiveMember  \
# 0       2      0.00              1          1               1
# 1       1  83807.86              1          0               1
#
#    EstimatedSalary  Exited
# 0        101348.88       1
# 1        112542.58       0

# %%
ds.isnull().any()
# Out:
# RowNumber          False
# CustomerId         False
# Surname            False
# CreditScore        False
# Geography          False
# Gender             False
# Age                False
# Tenure             False
# Balance            False
# NumOfProducts      False
# HasCrCard          False
# IsActiveMember     False
# EstimatedSalary    False
# Exited             False
# dtype: bool

# %%
ds.describe()
# Out:
#          RowNumber    CustomerId   CreditScore           Age        Tenure  \
# count  10000.00000  1.000000e+04  10000.000000  10000.000000  10000.000000
# mean    5000.50000  1.569094e+07    650.528800     38.921800      5.012800
# std     2886.89568  7.193619e+04     96.653299     10.487806      2.892174
# min        1.00000  1.556570e+07    350.000000     18.000000      0.000000
# 25%     2500.75000  1.562853e+07    584.000000     32.000000      3.000000
# 50%     5000.50000  1.569074e+07    652.000000     37.000000      5.000000
# 75%     7500.25000  1.575323e+07    718.000000     44.000000      7.000000
# max    10000.00000  1.581569e+07    850.000000     92.000000     10.000000
#
#              Balance  NumOfProducts    HasCrCard  IsActiveMember  \
# count   10000.000000   10000.000000  10000.00000    10000.000000
# mean    76485.889288       1.530200      0.70550        0.515100
# std     62397.405202       0.581654      0.45584        0.499797
# ...

# %% [markdown]
# 5. Handle the Missing values.

# %%
dataset.head()
# Out:
#    RowNumber  CustomerId   Surname  CreditScore Geography  Gender  Age  \
# 0          1    15634602  Hargrave          619    France  Female   42
# 1          2    15647311      Hill          608     Spain  Female   41
# 2          3    15619304      Onio          502    France  Female   42
# 3          4    15701354      Boni          699    France  Female   39
# 4          5    15737888  Mitchell          850     Spain  Female   43
#
#    Tenure    Balance  NumOfProducts  HasCrCard  IsActiveMember  \
# 0       2       0.00              1          1               1
# 1       1   83807.86              1          0               1
# 2       8  159660.80              3          1               0
# 3       1       0.00              2          0               0
# 4       2  125510.82              1          1               1
#
#    EstimatedSalary  Exited
# 0        101348.88       1
# 1        112542.58       0
# 2        113931.57       1
# 3         93826.63       0
# ...

# %%
dataset.isnull().sum()
# Out:
# RowNumber          0
# CustomerId         0
# Surname            0
# CreditScore        0
# Geography          0
# Gender             0
# Age                0
# Tenure             0
# Balance            0
# NumOfProducts      0
# HasCrCard          0
# IsActiveMember     0
# EstimatedSalary    0
# Exited             0
# dtype: int64

# %% [markdown]
#  dataset is not having any missing or null values.

# %% [markdown]
# 6. Find the outliers and replace the outliers

# %%
dataset.skew()
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   """Entry point for launching an IPython kernel.
# RowNumber          0.000000
# CustomerId         0.001149
# CreditScore       -0.071607
# Age                1.011320
# Tenure             0.010991
# Balance           -0.141109
# NumOfProducts      0.745568
# HasCrCard         -0.901812
# IsActiveMember    -0.060437
# EstimatedSalary    0.002085
# Exited             1.471611
# dtype: float64

# %%
sns.boxplot(dataset["Age"])
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
q1= dataset["Age"].describe()["25%"]
q3= dataset["Age"].describe()["75%"]

# %%
q1
# Out:
# 32.0

# %%
q3
# Out:
# 44.0

# %%
iqr=q3-q1
iqr
# Out:
# 12.0

# %%
l_b=q1-(1.5*iqr)
u_b=q3+(1.5*iqr)

# %%
l_b
# Out:
# 14.0

# %%
l_b=q1-(1.5*iqr)
u_b=q3+(1.5*iqr)

# %%
l_b
# Out:
# 14.0

# %%
u_b
# Out:
# 62.0

# %%
dataset[dataset["Age"]<l_b]
# Out:
# Empty DataFrame
# Columns: [RowNumber, CustomerId, Surname, CreditScore, Geography, Gender, Age, Tenure, Balance, NumOfProducts, HasCrCard, IsActiveMember, EstimatedSalary, Exited]
# Index: []

# %%
dataset[dataset["Age"]>u_b].head()
# Out:
#      RowNumber  CustomerId   Surname  CreditScore Geography  Gender  Age  \
# 58          59    15623944     T'ien          511     Spain  Female   66
# 85          86    15805254   Ndukaku          652     Spain  Female   75
# 104        105    15804919  Dunbabin          670     Spain  Female   65
# 158        159    15589975   Maclean          646    France  Female   73
# 181        182    15789669      Hsia          510    France    Male   65
#
#      Tenure   Balance  NumOfProducts  HasCrCard  IsActiveMember  \
# 58        4      0.00              1          1               0
# 85       10      0.00              2          1               1
# 104       1      0.00              1          1               1
# 158       6  97259.25              1          0               1
# 181       2      0.00              2          1               1
#
#      EstimatedSalary  Exited
# 58           1643.11       1
# 85         114675.75       0
# 104        177655.68       1
# ...

# %%
dataset.dtypes
# Out:
# RowNumber            int64
# CustomerId           int64
# Surname             object
# CreditScore          int64
# Geography           object
# Gender              object
# Age                  int64
# Tenure               int64
# Balance            float64
# NumOfProducts        int64
# HasCrCard            int64
# IsActiveMember       int64
# EstimatedSalary    float64
# Exited               int64
# dtype: object

# %%
outlier_list=list(dataset[dataset["Age"]>u_b]["Age"])
outlier_list
# Out:
# [66,
#  75,
#  65,
#  73,
#  65,
#  72,
#  67,
#  67,
#  79,
#  80,
#  68,
#  75,
#  66,
#  66,
#  70,
#  63,
#  72,
#  64,
#  64,
#  70,
#  67,
#  82,
#  63,
#  69,
#  65,
#  69,
#  64,
#  65,
#  74,
#  67,
#  66,
#  67,
#  63,
#  70,
#  71,
#  72,
#  67,
#  74,
#  76,
#  66,
#  63,
#  66,
#  68,
#  67,
#  63,
#  71,
#  66,
#  69,
#  73,
#  65,
#  66,
#  64,
#  69,
#  64,
#  77,
#  74,
#  65,
#  70,
#  67,
#  69,
#  67,
#  74,
#  69,
#  74,
#  74,
#  64,
#  63,
#  63,
#  70,
#  74,
#  65,
#  72,
#  77,
#  66,
#  65,
#  74,
#  88,
#  63,
#  71,
#  63,
#  64,
#  67,
#  70,
#  68,
#  72,
#  71,
#  66,
#  75,
#  67,
#  73,
#  69,
#  76,
#  63,
#  85,
#  67,
#  74,
#  76,
#  66,
#  69,
#  66,
#  72,
#  63,
#  71,
#  63,
#  74,
#  67,
#  72,
#  72,
#  66,
#  84,
#  71,
#  66,
#  63,
#  74,
#  69,
#  84,
#  67,
#  64,
#  68,
#  66,
#  77,
#  70,
#  67,
#  79,
#  67,
#  76,
#  73,
#  66,
#  67,
#  64,
#  73,
#  76,
#  72,
#  64,
#  71,
#  63,
#  70,
#  65,
#  66,
#  65,
#  80,
#  66,
# ...

# %%
outlier_dict={}.fromkeys(outlier_list,u_b)
outlier_dict
# Out:
# {66: 62.0,
#  75: 62.0,
#  65: 62.0,
#  73: 62.0,
#  72: 62.0,
#  67: 62.0,
#  79: 62.0,
#  80: 62.0,
#  68: 62.0,
#  70: 62.0,
#  63: 62.0,
#  64: 62.0,
#  82: 62.0,
#  69: 62.0,
#  74: 62.0,
#  71: 62.0,
#  76: 62.0,
#  77: 62.0,
#  88: 62.0,
#  85: 62.0,
#  84: 62.0,
#  78: 62.0,
#  81: 62.0,
#  92: 62.0,
#  83: 62.0}

# %% [markdown]
# After removing outliers

# %%
dataset["Age"]=dataset["Age"].replace(outlier_dict)
sns.boxplot(dataset["Age"])
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %% [markdown]
# 7. Check for Categorical columns and perform encoding.

# %%
dataset.dtypes
# Out:
# RowNumber            int64
# CustomerId           int64
# Surname             object
# CreditScore          int64
# Geography           object
# Gender              object
# Age                float64
# Tenure               int64
# Balance            float64
# NumOfProducts        int64
# HasCrCard            int64
# IsActiveMember       int64
# EstimatedSalary    float64
# Exited               int64
# dtype: object

# %%
from sklearn.preprocessing import LabelEncoder

# %%
le=LabelEncoder()
dataset['Geography']=le.fit_transform(dataset['Geography'])
dataset['Gender']=le.fit_transform(dataset['Gender'])

# %%
dataset.head()
# Out:
#    RowNumber  CustomerId   Surname  CreditScore  Geography  Gender   Age  \
# 0          1    15634602  Hargrave          619          0       0  42.0
# 1          2    15647311      Hill          608          2       0  41.0
# 2          3    15619304      Onio          502          0       0  42.0
# 3          4    15701354      Boni          699          0       0  39.0
# 4          5    15737888  Mitchell          850          2       0  43.0
#
#    Tenure    Balance  NumOfProducts  HasCrCard  IsActiveMember  \
# 0       2       0.00              1          1               1
# 1       1   83807.86              1          0               1
# 2       8  159660.80              3          1               0
# 3       1       0.00              2          0               0
# 4       2  125510.82              1          1               1
#
#    EstimatedSalary  Exited
# 0        101348.88       1
# 1        112542.58       0
# 2        113931.57       1
# 3         93826.63       0
# ...

# %% [markdown]
# 8. Split the data into dependent and independent variables.

# %%
y=dataset['Exited']
x=dataset.drop(columns=['Exited','RowNumber','Surname'],axis=1)

# %%
y
# Out:
# 0       1
# 1       0
# 2       1
# 3       0
# 4       0
#        ..
# 9995    0
# 9996    0
# 9997    1
# 9998    1
# 9999    0
# Name: Exited, Length: 10000, dtype: int64

# %%
x
# Out:
#       CustomerId  CreditScore  Geography  Gender   Age  Tenure    Balance  \
# 0       15634602          619          0       0  42.0       2       0.00
# 1       15647311          608          2       0  41.0       1   83807.86
# 2       15619304          502          0       0  42.0       8  159660.80
# 3       15701354          699          0       0  39.0       1       0.00
# 4       15737888          850          2       0  43.0       2  125510.82
# ...          ...          ...        ...     ...   ...     ...        ...
# 9995    15606229          771          0       1  39.0       5       0.00
# 9996    15569892          516          0       1  35.0      10   57369.61
# 9997    15584532          709          0       0  36.0       7       0.00
# 9998    15682355          772          1       1  42.0       3   75075.31
# 9999    15628319          792          0       0  28.0       4  130142.79
#
#       NumOfProducts  HasCrCard  IsActiveMember  EstimatedSalary
# ...

# %% [markdown]
# 9. Scale the independent variables

# %%
col_names=x.columns
from sklearn.preprocessing import scale

# %%
x=scale(x) # conver to array
x
# Out:
# array([[-0.78321342, -0.32622142, -0.90188624, ...,  0.64609167,
#          0.97024255,  0.02188649],
#        [-0.60653412, -0.44003595,  1.51506738, ..., -1.54776799,
#          0.97024255,  0.21653375],
#        [-0.99588476, -1.53679418, -0.90188624, ...,  0.64609167,
#         -1.03067011,  0.2406869 ],
#        ...,
#        [-1.47928179,  0.60498839, -0.90188624, ..., -1.54776799,
#          0.97024255, -1.00864308],
#        [-0.11935577,  1.25683526,  0.30659057, ...,  0.64609167,
#         -1.03067011, -0.12523071],
#        [-0.87055909,  1.46377078, -0.90188624, ...,  0.64609167,
#         -1.03067011, -1.07636976]])

# %%
x=pd.DataFrame(x,columns=col_names) #Convert the array back to the DataFrame
x
# Out:
#       CustomerId  CreditScore  Geography    Gender       Age    Tenure  \
# 0      -0.783213    -0.326221  -0.901886 -1.095988  0.342615 -1.041760
# 1      -0.606534    -0.440036   1.515067 -1.095988  0.240011 -1.387538
# 2      -0.995885    -1.536794  -0.901886 -1.095988  0.342615  1.032908
# 3       0.144767     0.501521  -0.901886 -1.095988  0.034803 -1.387538
# 4       0.652659     2.063884   1.515067 -1.095988  0.445219 -1.041760
# ...          ...          ...        ...       ...       ...       ...
# 9995   -1.177652     1.246488  -0.901886  0.912419  0.034803 -0.004426
# 9996   -1.682806    -1.391939  -0.901886  0.912419 -0.375612  1.724464
# 9997   -1.479282     0.604988  -0.901886 -1.095988 -0.273008  0.687130
# 9998   -0.119356     1.256835   0.306591  0.912419  0.342615 -0.695982
# 9999   -0.870559     1.463771  -0.901886 -1.095988 -1.093840 -0.350204
#
#        Balance  NumOfProducts  HasCrCard  IsActiveMember  EstimatedSalary
# ...

# %% [markdown]
# 10. Split the data into training and testing

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=0)

# %%
x_train.shape
# Out:
# (8000, 11)

# %%
x_test.shape
# Out:
# (2000, 11)

# %%
y_train.shape
# Out:
# (8000,)

# %%
y_test.shape
# Out:
# (2000,)
